# %% [markdown]
# # Linear Regression Lab

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("housing.csv")
df
# Out:
#     sqft  bedrooms   price
# 0   2104         3  399900
# 1   1600         3  329900
# 2   2400         3  369000
# 3   1416         2  232000
# 4   3000         4  539900
# 5   1985         4  299900
# 6   1534         3  314900
# 7   1427         3  198999
# 8   1380         3  212000
# 9   1494         3  242500
# 10  1940         4  239999
# 11  2000         3  347000
# 12  1890         3  329999
# 13  4478         5  699900
# 14  1268         3  259900
# 15  2300         4  449900
# 16  1320         2  299900
# 17  1236         3  199900
# 18  2609         4  499998
# 19  3031         4  599000
# 20  1767         3  252900
# 21  1888         2  255000
# 22  1604         3  242900
# 23  1962         4  259900
# 24  3890         3  573900
# 25  1100         3  249900
# 26  1458         3  464500
# 27  2526         3  469000
# 28  2200         3  475000
# 29  2637         3  299900
# 30  1839         2  349900
# 31  1000         1  169900
# 32  2040         4  314900
# 33  3137         3  579900
# 34  1811         4  285900
# 35  1437         3  249900
# 36  1239         3  229900
# 37  2132         4  345000
# 38  4215         4  549000
# 39  2162         4  287000
# 40  1664         2  368500
# 41  2238         3  329900
# 42  2567         4  314000
# 43  1200         3  299000
# 44   852         2  179900
# 45  1852         4  299900
# 46  1203         3  239500

# %%
# Set up our training data
x_train = df['sqft'].to_numpy()
y_train = df['price'].to_numpy()

# To use only a subset of the training data, use a slice of the arrays above.

print("Training data for x: ", x_train)
print("Training data for y: ", y_train)
# Out:
# Training data for x:  [2104 1600 2400 1416 3000 1985 1534 1427 1380 1494 1940 2000 1890 4478
#  1268 2300 1320 1236 2609 3031 1767 1888 1604 1962 3890 1100 1458 2526
#  2200 2637 1839 1000 2040 3137 1811 1437 1239 2132 4215 2162 1664 2238
#  2567 1200  852 1852 1203]
# Training data for y:  [399900 329900 369000 232000 539900 299900 314900 198999 212000 242500
#  239999 347000 329999 699900 259900 449900 299900 199900 499998 599000
#  252900 255000 242900 259900 573900 249900 464500 469000 475000 299900
#  349900 169900 314900 579900 285900 249900 229900 345000 549000 287000
#  368500 329900 314000 299000 179900 299900 239500]

# %%
# Make a nice plot

plt.scatter(x_train, y_train)
plt.show()

# %%
# Make a nice plot with a line based on the equation y = wx + b

plt.scatter(x_train, y_train)

# Set up dummy values for w and b
w = 175
b = 0
 
# Generate points on our line y = wx + b to graph
line_x_points = np.linspace(min(x_train), max(x_train), 100)
line_y_points = [w * x + b for x in line_x_points]

plt.plot(line_x_points, line_y_points, c='red')
plt.show()

# %%
# Let's turn it into a function:

def make_plot(x_train, y_train, w, b):
    plt.scatter(x_train, y_train)

    line_x_points = np.linspace(min(x_train), max(x_train), 100)
    line_y_points = [w * x + b for x in line_x_points]
    
    plt.plot(line_x_points, line_y_points, c='red')
    plt.show()
    
make_plot(x_train, y_train, 0, 0)

# %%
# Let's define a function to predict y = f(x) = wx + b

def make_prediction(x, w, b):
    return w * x + b

# %%
# Let's define a function to compute the cost J(w, b) on a set of data:

def compute_cost(x_data, y_data, w, b):
    """
    x_data and y_data are lists
    w and b are scalars
    return: cost
    """
    m = len(x_data) 
    
    total_cost = 0
    
    # summation 
    for i in range(0, m):
        y = y_data[i] # y^(i)
        y_hat = make_prediction(x_data[i], w, b) #y^(i) prediction 
        
        cost = (y_hat - y)**2
        
        total_cost += cost
    
    return total_cost/ (2 * m)

# %%
# Output total cost for our data set:

w = 120
b = 100000

print(compute_cost(x_train, y_train, w, b))
# Out:
# 2123393642.6276596

# %%
# Let's write a function to compute the gradient:

def compute_gradient(x_data, y_data, w, b):
    """
    x_data and y_data are lists
    w and b are scalars
    return: gradient of w, gradient of b
    """
    
    m = len(x_data) 
    gradient_w = 0
    gradient_b = 0
        
    # summation 
    for i in range(0, m):
        y = y_data[i] # y^(i)
        y_hat = make_prediction(x_data[i], w, b) #y^(i) prediction 
        
        grad_w = (y_hat - y) * x_data[i]
        gradient_w += grad_w 
        
        grad_b = (y_hat - y)
        gradient_b += grad_b
        
    
    return gradient_w / m, gradient_b / m

# %%
# Let's write code to run gradient descent:

w = 0
b = 0
ALPHA = .00000001

J_list = []

# must run until convergence 
for ctr in range(0, 100):
    # checks to see how each iteration changes the w and b values 
    print("Iteration: ", ctr)
    print("w = ", w, "b = ", b)
    cost = compute_cost(x_train, y_train, w, b)
    print("cost = ", cost)
    J_list.append(cost)
    
    # has the derivatives after the 1/m reduction 
    gradient_w, gradient_b = compute_gradient(x_train, y_train, w, b)
    
    # this part does the gradient descent formulas 
    w = w - ALPHA * gradient_w 
    b = b - ALPHA * gradient_b
    
    print()
    print("---------------------------------------------")
    
    
print("Final w and b:", w, b)
# Out:
# Iteration:  0
# w =  0 b =  0
# cost =  65591548106.45744
#
# ---------------------------------------------
# Iteration:  1
# w =  7.642091281914894 b =  0.003404126595744681
# cost =  59886323167.92605
#
# ---------------------------------------------
# Iteration:  2
# w =  14.931053805255132 b =  0.006655359300550007
# cost =  54696174895.445564
#
# ---------------------------------------------
# Iteration:  3
# w =  21.883205082447454 b =  0.009760763095397319
# cost =  49974601358.801
#
# ---------------------------------------------
# Iteration:  4
# w =  28.514108619892944 b =  0.012727076499850816
# cost =  45679298895.05728
#
# ---------------------------------------------
# Iteration:  5
# w =  34.838608759373734 b =  0.015560726657314993
# cost =  41771783082.396805
#
# ---------------------------------------------
# Iteration:  6
# w =  40.87086390949428 b =  0.01826784372322657
# cost =  38217043933.03417
#
# ---------------------------------------------
# Iteration:  7
# w =  46.624378241551156 b =  0.020854274588391203
# cost =  34983232215.85608
#
# ---------------------------------------------
# Iteration:  8
# w =  52.112031920787636 b =  0.023325595968186855
# cost =  32041374098.345585
#
# ---------------------------------------------
# Iteration:  9
# w =  57.34610994071058 b =  0.025687126886936106
# cost =  29365111551.08187
#
# ---------------------------------------------
# Iteration:  10
# w =  62.33832962501992 b =  0.02794394058539571
# cost =  26930466188.929157
#
# ---------------------------------------------
# Iteration:  11
# w =  67.09986685871807 b =  0.030100875878020163
# cost =  24715624433.01397
#
# ---------------------------------------------
# Iteration:  12
# w =  71.6413811071221 b =  0.03216254798542439
# cost =  22700742068.616554
#
# ---------------------------------------------
# Iteration:  13
# w =  75.9730392787874 b =  0.03413335886629574
# cost =  20867766447.8826
#
# ---------------------------------------------
# Iteration:  14
# w =  80.10453848576405 b =  0.03601750707188493
# cost =  19200274744.353405
#
# ---------------------------------------------
# Iteration:  15
# w =  84.0451277521384 b =  0.037818997145136805
# cost =  17683326810.131084
#
# ---------------------------------------------
# Iteration:  16
# w =  87.80362871945766 b =  0.03954164858550235
# cost =  16303331317.329847
#
# ---------------------------------------------
# Iteration:  17
# w =  91.3884553953903 b =  0.04118910439950117
# cost =  15047923984.487371
#
# ---------------------------------------------
# Iteration:  18
# w =  94.80763298983237 b =  0.042764839256176225
# cost =  13905856796.886868
#
# ---------------------------------------------
# Iteration:  19
# w =  98.06881588062787 b =  0.04427216726569806
# cost =  12866897228.242466
#
# ---------------------------------------------
# Iteration:  20
# w =  101.17930474912178 b =  0.0457142493985323
# cost =  11921736560.809124
#
# ---------------------------------------------
# Iteration:  21
# w =  104.14606292390698 b =  0.0470941005617793
# cost =  11061906482.4969
#
# ---------------------------------------------
# Iteration:  22
# w =  106.97573196935268 b =  0.048414596348527475
# cost =  10279703213.728807
#
# ---------------------------------------------
# Iteration:  23
# w =  109.67464655381214 b =  0.04967847947532999
# cost =  9568118484.244972
#
# ---------------------------------------------
# Iteration:  24
# w =  112.24884863079434 b =  0.050888365922215816
# cost =  8920776741.429401
#
# ---------------------------------------------
# Iteration:  25
# w =  114.70410096484655 b =  0.05204675078898091
# cost =  8331878027.56754
#
# ---------------------------------------------
# Iteration:  26
# w =  117.04590003242751 b =  0.05315601388086948
# cost =  7796146014.23473
#
# ---------------------------------------------
# Iteration:  27
# w =  119.27948832665213 b =  0.05421842503614993
# cost =  7308780728.22172
#
# ---------------------------------------------
# Iteration:  28
# w =  121.40986609345357 b =  0.05523614920751212
# cost =  6865415545.437756
#
# ---------------------------------------------
# Iteration:  29
# w =  123.44180252543626 b =  0.05621125130866134
# cost =  6462078067.471766
#
# ---------------------------------------------
# Iteration:  30
# w =  125.37984643847882 b =  0.05714570083695908
# cost =  6095154530.278902
#
# ---------------------------------------------
# Iteration:  31
# w =  127.22833645498848 b =  0.05804137628245887
# cost =  5761357426.106839
#
# ---------------------------------------------
# Iteration:  32
# w =  128.99141071660353 b =  0.058900069333207766
# cost =  5457696048.565374
#
# ---------------------------------------------
# Iteration:  33
# w =  130.6730161480875 b =  0.05972348888622757
# cost =  5181449696.933389
#
# ---------------------------------------------
# Iteration:  34
# w =  132.27691729315364 b =  0.060513264873155025
# cost =  4930143299.623074
#
# ---------------------------------------------
# Iteration:  35
# w =  133.80670474200014 b =  0.06127095190910539
# cost =  4701525238.396075
#
# ---------------------------------------------
# Iteration:  36
# w =  135.26580316942244 b =  0.06199803277292784
# cost =  4493547174.64423
#
# ---------------------------------------------
# Iteration:  37
# w =  136.65747900149753 b =  0.06269592172664387
# cost =  4304345696.985324
#
# ---------------------------------------------
# Iteration:  38
# w =  137.98484772800273 b =  0.0633659676814998
# cost =  4132225625.7427816
#
# ---------------------------------------------
# Iteration:  39
# w =  139.2508808769396 b =  0.06400945721772107
# cost =  3975644824.723099
#
# ---------------------------------------------
# Iteration:  40
# w =  140.45841266677624 b =  0.06462761746472855
# cost =  3833200384.209868
#
# ---------------------------------------------
# Iteration:  41
# w =  141.6101463513002 b =  0.06522161884826465
# cost =  3703616051.37882
#
# ---------------------------------------------
# Iteration:  42
# w =  142.7086602712858 b =  0.06579257771057921
# cost =  3585730795.5147047
#
# ---------------------------------------------
# Iteration:  43
# w =  143.75641362652382 b =  0.06634155880954076
# cost =  3478488405.578358
#
# ---------------------------------------------
# Iteration:  44
# w =  144.75575198113484 b =  0.06686957770226788
# cost =  3380928026.921767
#
# ---------------------------------------------
# Iteration:  45
# w =  145.70891251449095 b =  0.06737760301861677
# cost =  3292175552.363324
#
# ---------------------------------------------
# Iteration:  46
# w =  146.61802902950075 b =  0.06786655862961465
# cost =  3211435790.4903603
#
# ---------------------------------------------
# Iteration:  47
# w =  147.4851367294697 b =  0.06833732571569331
# cost =  3137985341.019587
#
# ---------------------------------------------
# Iteration:  48
# w =  148.3121767742292 b =  0.06879074473935293
# cost =  3071166113.3812294
#
# ---------------------------------------------
# Iteration:  49
# w =  149.10100062573443 b =  0.06922761732667222
# cost =  3010379430.4555163
#
# ---------------------------------------------
# Iteration:  50
# w =  149.85337419285912 b =  0.0696487080618771
# cost =  2955080664.6331334
#
# ---------------------------------------------
# Iteration:  51
# w =  150.5709817846659 b =  0.07005474619898515
# cost =  2904774358.140538
#
# ---------------------------------------------
# Iteration:  52
# w =  151.25542988100239 b =  0.07044642729435775
# cost =  2859009783.9099827
#
# ---------------------------------------------
# Iteration:  53
# w =  151.90825072886426 b =  0.07082441476381467
# cost =  2817376907.221152
#
# ---------------------------------------------
# Iteration:  54
# w =  152.53090577257592 b =  0.07118934136779678
# cost =  2779502711.932142
#
# ---------------------------------------------
# Iteration:  55
# w =  153.12478892546824 b =  0.07154181062790191
# cost =  2745047858.3840723
#
# ---------------------------------------------
# Iteration:  56
# w =  153.69122969037716 b =  0.07188239817796473
# cost =  2713703643.0353193
#
# ---------------------------------------------
# Iteration:  57
# w =  154.23149613594921 b =  0.07221165305270552
# cost =  2685189232.5847425
#
# ---------------------------------------------
# Iteration:  58
# w =  154.7467977354167 b =  0.07253009891683249
# cost =  2659249147.802602
#
# ---------------------------------------------
# Iteration:  59
# w =  155.2382880741975 b =  0.07283823523734922
# cost =  2635650974.525195
#
# ---------------------------------------------
# Iteration:  60
# w =  155.7070674323813 b =  0.07313653840169178
# cost =  2614183281.304467
#
# ---------------------------------------------
# Iteration:  61
# w =  156.1541852478831 b =  0.07342546278419838
# cost =  2594653725.0554953
#
# ---------------------------------------------
# Iteration:  62
# w =  156.58064246577837 b =  0.0737054417632993
# cost =  2576887327.7290874
#
# ---------------------------------------------
# Iteration:  63
# w =  156.98739377907918 b =  0.07397688869170402
# cost =  2560724908.5691037
#
# ---------------------------------------------
# Iteration:  64
# w =  157.37534976596785 b =  0.0742401978217576
# cost =  2546021657.9080143
#
# ---------------------------------------------
# Iteration:  65
# w =  157.74537892827223 b =  0.07449574518803785
# cost =  2532645839.722468
#
# ---------------------------------------------
# Iteration:  66
# w =  158.0983096357465 b =  0.07474388944916906
# cost =  2520477611.3241577
#
# ---------------------------------------------
# Iteration:  67
# w =  158.4349319805097 b =  0.07498497269073687
# cost =  2509407949.610863
#
# ---------------------------------------------
# Iteration:  68
# w =  158.75599954579386 b =  0.07521932119110177
# cost =  2499337674.257229
#
# ---------------------------------------------
# Iteration:  69
# w =  159.06223109296087 b =  0.07544724615182556
# cost =  2490176559.093406
#
# ---------------------------------------------
# Iteration:  70
# w =  159.35431217056524 b =  0.07566904439434602
# cost =  2481842523.7098427
#
# ---------------------------------------------
# Iteration:  71
# w =  159.6328966490645 b =  0.07588499902445928
# cost =  2474260898.045247
#
# ---------------------------------------------
# Iteration:  72
# w =  159.89860818461312 b =  0.07609538006609762
# cost =  2467363753.368713
#
# ---------------------------------------------
# Iteration:  73
# w =  160.152041615217 b =  0.07630044506582136
# cost =  2461089293.6618233
#
# ---------------------------------------------
# Iteration:  74
# w =  160.3937642923737 b =  0.07650043966937817
# cost =  2455381301.9477444
#
# ---------------------------------------------
# Iteration:  75
# w =  160.62431735117985 b =  0.07669559817162047
# cost =  2450188636.6065836
#
# ---------------------------------------------
# Iteration:  76
# w =  160.84421692174897 b =  0.07688614404101211
# cost =  2445464773.1641955
#
# ---------------------------------------------
# Iteration:  77
# w =  161.0539552846514 b =  0.07707229041989835
# cost =  2441167387.4490213
#
# ---------------------------------------------
# Iteration:  78
# w =  161.25400197296358 b =  0.07725424060165921
# cost =  2437257976.382167
#
# ---------------------------------------------
# Iteration:  79
# w =  161.44480482339299 b =  0.07743218848581432
# cost =  2433701513.003158
#
# ---------------------------------------------
# Iteration:  80
# w =  161.62679097883256 b =  0.07760631901209812
# cost =  2430466132.64052
#
# ---------------------------------------------
# Iteration:  81
# w =  161.80036784458864 b =  0.07777680857447715
# cost =  2427522847.4153514
#
# ---------------------------------------------
# Iteration:  82
# w =  161.9659240004231 b =  0.07794382541603623
# cost =  2424845286.519974
#
# ---------------------------------------------
# Iteration:  83
# w =  162.12383007045142 b =  0.0781075300056176
# cost =  2422409459.9446387
#
# ---------------------------------------------
# Iteration:  84
# w =  162.27443955284443 b =  0.0782680753970562
# cost =  2420193543.5353494
#
# ---------------------------------------------
# Iteration:  85
# w =  162.41808961119054 b =  0.07842560757181521
# cost =  2418177683.456996
#
# ---------------------------------------------
# Iteration:  86
# w =  162.55510182929058 b =  0.07858026576578904
# cost =  2416343818.309881
#
# ---------------------------------------------
# Iteration:  87
# w =  162.68578293107475 b =  0.07873218278100513
# cost =  2414675517.3058376
#
# ---------------------------------------------
# Iteration:  88
# w =  162.8104254672534 b =  0.0788814852829227
# cost =  2413157833.054046
#
# ---------------------------------------------
# Iteration:  89
# w =  162.92930847023868 b =  0.07902829408399364
# cost =  2411777167.6376085
#
# ---------------------------------------------
# Iteration:  90
# w =  163.04269807880343 b =  0.0791727244141206
# cost =  2410521150.7809114
#
# ---------------------------------------------
# Iteration:  91
# w =  163.15084813387546 b =  0.0793148861786176
# cost =  2409378529.016252
#
# ---------------------------------------------
# Iteration:  92
# w =  163.25400074680127 b =  0.07945488420425073
# cost =  2408339064.856664
#
# ---------------------------------------------
# Iteration:  93
# w =  163.35238684135115 b =  0.07959281847390971
# cost =  2407393445.071574
#
# ---------------------------------------------
# Iteration:  94
# w =  163.44622667067907 b =  0.07972878435043558
# cost =  2406533197.243494
#
# ---------------------------------------------
# Iteration:  95
# w =  163.5357303103947 b =  0.07986287279010576
# cost =  2405750613.8580875
#
# ---------------------------------------------
# Iteration:  96
# w =  163.62109812885143 b =  0.07999517054625425
# cost =  2405038683.2475195
#
# ---------------------------------------------
# Iteration:  97
# w =  163.70252123570302 b =  0.08012576036348294
# cost =  2404391026.7683306
#
# ---------------------------------------------
# Iteration:  98
# w =  163.78018190973327 b =  0.08025472116289861
# cost =  2403801841.6510153
#
# ---------------------------------------------
# Iteration:  99
# w =  163.8542540069163 b =  0.08038212821879054
# cost =  2403265849.009208
#
# ---------------------------------------------
# Final w and b: 163.9249033496211 0.08050805332714407

# %%
# Let's plot the cost as a function of number of iterations of the
# gradient descent algorithm.

plt.scatter(range(0, len(J_list)), J_list)

# %%
# Produce final plot of our data and our line:

# minimizes the error
# as small as the error line can get 
# cost would be 2403265849.009208
make_plot(x_train, y_train, 163.9249033496211, 0.08050805332714407)

# %%
# Make a new prediction:

sqft = 2000
prediction = make_prediction(sqft, w, b)

# rounds up 2 decimal places 
prediction = round(prediction, 2)

print("A house with", sqft, "square feet would sell for around", prediction, "dollars.")
# Out:
# A house with 2000 square feet would sell for around 327849.89 dollars.
